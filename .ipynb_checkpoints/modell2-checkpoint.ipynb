# %%
import os
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from tqdm import tqdm
import clean_data_v3 as clean_data

# Aktuelles Arbeitsverzeichnis abrufen
current_dir = os.getcwd().replace("\\", "/")

# Trainings- und Testdaten einlesen
df_train = pd.read_csv(current_dir + "/data/train.csv")
df_test = pd.read_csv(current_dir + "/data/test.csv")

# Daten bereinigen
df_train = clean_data.clean_data(df_train, is_train=True)
df_test = clean_data.clean_data(df_test, is_train=False)

# Überprüfen, ob 'efs' nach dem Cleaning vorhanden ist
if 'efs' not in df_train:
    raise ValueError("Fehlende Zielvariable ('efs') nach dem Cleaning!")

# Features definieren (nur numerische Spalten außer 'efs')
X_train = df_train.drop(columns=['efs', 'efs_time'], errors='ignore')
X_test = df_test.drop(columns=['efs', 'efs_time'], errors='ignore')
y_train = df_train['efs'].astype(float)  # Sicherstellen, dass y_train numerisch ist

# Sicherstellen, dass Test-Features mit Trainings-Features übereinstimmen
missing_cols = set(X_train.columns) - set(X_test.columns)
if missing_cols:
    print(f"Warnung: Die Testdaten fehlen folgende Spalten {missing_cols}. Diese werden mit 0 aufgefüllt.")
    for col in missing_cols:
        X_test[col] = 0

# Sicherstellen, dass die Spalten in der gleichen Reihenfolge sind
X_test = X_test[X_train.columns]

# XGBRegressor initialisieren
xgb_model = XGBRegressor(
    n_estimators=500,
    learning_rate=0.05,
    max_depth=5,
    random_state=42
)

# Training mit Fortschrittsbalken
with tqdm(total=1, desc="Training des Modells") as pbar:
    xgb_model.fit(X_train, y_train)
    pbar.update(1)

# Vorhersagen für Testdaten (Risikoscore für efs)
risk_scores = xgb_model.predict(X_test)

# Ergebnisse speichern
results = pd.DataFrame({'ID': df_test.index, 'risk_score': risk_scores})
results.head(5)
# Out:
# ℹ️ Kategorische Spalte 'dri_score': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Kategorische Spalte 'psych_disturb': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Kategorische Spalte 'cyto_score': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Kategorische Spalte 'diabetes': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Numerische Spalte 'hla_match_c_high': Fehlende Werte mit Median auffüllen.
# ℹ️ Numerische Spalte 'hla_high_res_8': Fehlende Werte mit Median auffüllen.
# ℹ️ Kategorische Spalte 'arrhythmia': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Numerische Spalte 'hla_low_res_6': Fehlende Werte mit Median auffüllen.
# ℹ️ Kategorische Spalte 'vent_hist': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Kategorische Spalte 'renal_issue': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Kategorische Spalte 'pulm_severe': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Numerische Spalte 'hla_high_res_6': Fehlende Werte mit Median auffüllen.
# ℹ️ Kategorische Spalte 'cmv_status': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Numerische Spalte 'hla_high_res_10': Fehlende Werte mit Median auffüllen.
# ℹ️ Numerische Spalte 'hla_match_dqb1_high': Fehlende Werte mit Median auffüllen.
# ℹ️ Kategorische Spalte 'tce_imm_match': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Numerische Spalte 'hla_nmdp_6': Fehlende Werte mit Median auffüllen.
# ℹ️ Numerische Spalte 'hla_match_c_low': Fehlende Werte mit Median auffüllen.
# ℹ️ Kategorische Spalte 'rituximab': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Numerische Spalte 'hla_match_drb1_low': Fehlende Werte mit Median auffüllen.
# ℹ️ Numerische Spalte 'hla_match_dqb1_low': Fehlende Werte mit Median auffüllen.
# ℹ️ Kategorische Spalte 'cyto_score_detail': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Kategorische Spalte 'conditioning_intensity': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Kategorische Spalte 'ethnicity': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Kategorische Spalte 'obesity': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Kategorische Spalte 'mrd_hct': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Kategorische Spalte 'in_vivo_tcd': Fehlende Werte mit 'Unknown' auffüllen.
# ⚠️ Spalte 'tce_match' hat mehr als 60% fehlende Werte. Sie wird mit 0 gefüllt.
# ℹ️ Numerische Spalte 'hla_match_a_high': Fehlende Werte mit Median auffüllen.
# ℹ️ Kategorische Spalte 'hepatic_severe': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Numerische Spalte 'donor_age': Fehlende Werte mit Median auffüllen.
# ℹ️ Kategorische Spalte 'prior_tumor': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Numerische Spalte 'hla_match_b_low': Fehlende Werte mit Median auffüllen.
# ℹ️ Kategorische Spalte 'peptic_ulcer': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Numerische Spalte 'hla_match_a_low': Fehlende Werte mit Median auffüllen.
# ℹ️ Kategorische Spalte 'gvhd_proph': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Kategorische Spalte 'rheum_issue': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Kategorische Spalte 'sex_match': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Numerische Spalte 'hla_match_b_high': Fehlende Werte mit Median auffüllen.
# ℹ️ Numerische Spalte 'comorbidity_score': Fehlende Werte mit Median auffüllen.
# ℹ️ Numerische Spalte 'karnofsky_score': Fehlende Werte mit Median auffüllen.
# ℹ️ Kategorische Spalte 'hepatic_mild': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Kategorische Spalte 'tce_div_match': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Kategorische Spalte 'donor_related': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Kategorische Spalte 'melphalan_dose': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Numerische Spalte 'hla_low_res_8': Fehlende Werte mit Median auffüllen.
# ℹ️ Kategorische Spalte 'cardiac': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Numerische Spalte 'hla_match_drb1_high': Fehlende Werte mit Median auffüllen.
# ℹ️ Kategorische Spalte 'pulm_moderate': Fehlende Werte mit 'Unknown' auffüllen.
# ℹ️ Numerische Spalte 'hla_low_res_10': Fehlende Werte mit Median auffüllen.
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(0, inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(0, inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)
# /home/fa23b_eric/notebooks/My Projects/Mittelstufenprojekt/clean_data_v3.py:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(0, inplace=True)
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# /tmp/ipykernel_154131/741664715.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = 0
# Numerische Spalten mit NaN-Werten: []
# ⚠️ Problematische Spalten: ['dri_score_High - TED AML case <missing cytogenetics', 'dri_score_Intermediate - TED AML case <missing cytogenetics', 'dri_score_Missing disease status', 'dri_score_N/A - disease not classifiable', 'dri_score_N/A - non-malignant indication', 'dri_score_N/A - pediatric', 'dri_score_TBD cytogenetics', 'dri_score_Very high', 'cyto_score_Not tested', 'tbi_status_TBI + Cy +- Other', 'tbi_status_TBI +- Other, -cGy, fractionated', 'tbi_status_TBI +- Other, -cGy, single', 'tbi_status_TBI +- Other, -cGy, unknown dose', 'tbi_status_TBI +- Other, <=cGy', 'tbi_status_TBI +- Other, >cGy', 'tbi_status_TBI +- Other, unknown dose', 'graft_type_Peripheral blood', 'prim_disease_hct_Other acute leukemia', 'prim_disease_hct_Other leukemia', 'prim_disease_hct_Solid tumor', 'cyto_score_detail_Not tested', 'conditioning_intensity_N/A, F(pre-TED) not submitted', 'conditioning_intensity_No drugs reported', 'ethnicity_Non-resident of the U.S.', 'ethnicity_Not Hispanic or Latino', 'tce_match_Fully matched', 'tce_match_GvH non-permissive', 'tce_match_HvG non-permissive', 'gvhd_proph_CDselect alone', 'gvhd_proph_CSA + MMF +- others(not FK)', 'gvhd_proph_CSA + MTX +- others(not MMF,FK)', 'gvhd_proph_CSA +- others(not FK,MMF,MTX)', 'gvhd_proph_CSA alone', 'gvhd_proph_Cyclophosphamide +- others', 'gvhd_proph_Cyclophosphamide alone', 'gvhd_proph_FK+ MMF +- others', 'gvhd_proph_FK+ MTX +- others(not MMF)', 'gvhd_proph_FK+- others(not MMF,MTX)', 'gvhd_proph_No GvHD Prophylaxis', 'gvhd_proph_Other GVHD Prophylaxis', 'gvhd_proph_Parent Q = yes, but no agent', 'gvhd_proph_TDEPLETION +- other', 'gvhd_proph_TDEPLETION alone', 'race_group_Black or African-American', 'race_group_More than one race', 'race_group_Native Hawaiian or other Pacific Islander', 'tce_div_match_GvH non-permissive', 'tce_div_match_HvG non-permissive', 'tce_div_match_Permissive mismatched', 'melphalan_dose_N/A, Mel not given']
# ⚠️ Spalte 'cyto_score' hat mehr als 60% fehlende Werte. Sie wird mit 0 gefüllt.
# ℹ️ Numerische Spalte 'hla_match_c_high': Fehlende Werte mit Median auffüllen.
# ℹ️ Numerische Spalte 'hla_high_res_8': Fehlende Werte mit Median auffüllen.
# ℹ️ Numerische Spalte 'hla_high_res_10': Fehlende Werte mit Median auffüllen.
# ℹ️ Kategorische Spalte 'tce_imm_match': Fehlende Werte mit 'Unknown' auffüllen.
# ⚠️ Spalte 'cyto_score_detail' hat mehr als 60% fehlende Werte. Sie wird mit 0 gefüllt.
# ⚠️ Spalte 'conditioning_intensity' hat mehr als 60% fehlende Werte. Sie wird mit 0 gefüllt.
# ⚠️ Spalte 'mrd_hct' hat mehr als 60% fehlende Werte. Sie wird mit 0 gefüllt.
# ⚠️ Spalte 'tce_match' hat mehr als 60% fehlende Werte. Sie wird mit 0 gefüllt.
# ⚠️ Spalte 'donor_age' hat mehr als 60% fehlende Werte. Sie wird mit 0 gefüllt.
# ℹ️ Kategorische Spalte 'tce_div_match': Fehlende Werte mit 'Unknown' auffüllen.
# Numerische Spalten mit NaN-Werten: []
# ⚠️ Problematische Spalten: ['dri_score_N/A - non-malignant indication', 'tbi_status_TBI +- Other, >cGy', 'graft_type_Peripheral blood', 'gvhd_proph_Other GVHD Prophylaxis', 'race_group_More than one race']
# Warnung: Die Testdaten fehlen folgende Spalten {'prim_disease_hct_PCD', 'prim_disease_hct_HD', 'race_group_Native_Hawaiian_or_other_Pacific_Islander', 'tce_div_match_HvG_non_permissive', 'rituximab_Yes', 'ethnicity_Non_resident_of_the_U_S_', 'cardiac_Yes', 'hepatic_mild_Yes', 'tbi_status_TBI____Other____cGy', 'dri_score_TBD_cytogenetics', 'tbi_status_TBI___Cy____Other', 'prim_disease_hct_ALL', 'conditioning_intensity_Unknown', 'gvhd_proph_Cyclophosphamide_alone', 'prim_disease_hct_Other_leukemia', 'tbi_status_TBI____Other___cGy__unknown_dose', 'race_group_White', 'peptic_ulcer_Yes', 'gvhd_proph_FK__MMF____others', 'cmv_status____', 'tbi_status_TBI____Other__unknown_dose', 'prim_disease_hct_IMD', 'gvhd_proph_CDselect_alone', 'prim_disease_hct_SAA', 'renal_issue_Unknown', 'cyto_score_detail_Not_tested', 'prim_disease_hct_Other_acute_leukemia', 'prim_disease_hct_AML', 'prior_tumor_Yes', 'gvhd_proph_CSA___MTX____others_not_MMF_FK_', 'dri_score_N_A___disease_not_classifiable', 'dri_score_Unknown', 'pulm_severe_Unknown', 'ethnicity_Unknown', 'prim_disease_hct_Solid_tumor', 'cmv_status_Unknown', 'cyto_score_Not_tested', 'renal_issue_Yes', 'tbi_status_TBI____Other___cGy__fractionated', 'melphalan_dose_N_A__Mel_not_given', 'cyto_score_detail_Unknown', 'conditioning_intensity_NMA', 'pulm_moderate_Unknown', 'prim_disease_hct_MPN', 'donor_related_Related', 'gvhd_proph_CSA_alone', 'tbi_status_TBI____Other___cGy__single', 'prim_disease_hct_IPA', 'tce_div_match_Permissive_mismatched', 'hepatic_severe_Unknown', 'hepatic_mild_Unknown', 'prior_tumor_Unknown', 'pulm_severe_Yes', 'gvhd_proph_Cyclophosphamide____others', 'dri_score_Very_high', 'ethnicity_Not_Hispanic_or_Latino', 'conditioning_intensity_N_A__F_pre_TED__not_submitted', 'gvhd_proph_No_GvHD_Prophylaxis', 'sex_match_Unknown', 'obesity_Unknown', 'gvhd_proph_CSA____others_not_FK_MMF_MTX_', 'melphalan_dose_Unknown', 'gvhd_proph_CSA___MMF____others_not_FK_', 'sex_match_M_M', 'peptic_ulcer_Unknown', 'dri_score_Missing_disease_status', 'dri_score_Low', 'cyto_score_Unknown', 'hepatic_severe_Yes', 'mrd_hct_Unknown', 'diabetes_Yes', 'psych_disturb_Unknown', 'cyto_score_detail_Poor', 'cyto_score_Poor', 'diabetes_Unknown', 'prim_disease_hct_IIS', 'arrhythmia_Unknown', 'rheum_issue_Unknown', 'vent_hist_Unknown', 'race_group_Asian', 'prim_disease_hct_CML', 'dri_score_High___TED_AML_case__missing_cytogenetics', 'tce_imm_match_H_H', 'tce_imm_match_P_H', 'gvhd_proph_FK__MTX____others_not_MMF_', 'tce_imm_match_G_G', 'tce_imm_match_P_G', 'tce_imm_match_H_B', 'tce_imm_match_P_B', 'gvhd_proph_TDEPLETION_alone', 'donor_related_Unknown', 'psych_disturb_Yes', 'tce_match_Fully_matched', 'tce_imm_match_P_P', 'gvhd_proph_Parent_Q___yes__but_no_agent', 'rheum_issue_Yes', 'conditioning_intensity_No_drugs_reported', 'conditioning_intensity_RIC', 'cyto_score_Other', 'dri_score_N_A___pediatric', 'vent_hist_Yes', 'tce_div_match_GvH_non_permissive', 'cyto_score_Normal', 'gvhd_proph_Unknown', 'in_vivo_tcd_Unknown', 'race_group_Black_or_African_American', 'prim_disease_hct_MDS', 'cardiac_Unknown', 'rituximab_Unknown', 'gvhd_proph_TDEPLETION____other', 'obesity_Yes', 'arrhythmia_Yes', 'gvhd_proph_FK___others_not_MMF_MTX_', 'tce_match_GvH_non_permissive', 'prim_disease_hct_NHL', 'tce_match_HvG_non_permissive', 'dri_score_Intermediate', 'dri_score_Intermediate___TED_AML_case__missing_cytogenetics'}. Diese werden mit 0 aufgefüllt.
# Training des Modells:   0%|                               | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_154131/741664715.py in ?()
#      47 import os
#      48 import pandas as pd
# ---> 49 import numpy as np
#      50 from xgboost import XGBRegressor
#      51 from tqdm import tqdm
#      52 import clean_data_v3 as clean_data
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/core.py in ?(*args, **kwargs)
#     722                     raise TypeError(msg)
#     723                 warnings.warn(msg, FutureWarning)
#     724             for k, arg in zip(sig.parameters, args):
#     725                 kwargs[k] = arg
# --> 726             return func(**kwargs)
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/sklearn.py in ?(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1119                 callbacks=self.callbacks,
#    1120             )
#    1121
#    1122             self._set_evaluation_result(evals_result)
# -> 1123             return self
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/sklearn.py in ?(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     592     feature_types: Optional[FeatureTypes],
#     593 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     594     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     595     way."""
# --> 596     train_dmatrix = create_dmatrix(
#     597         data=X,
#     598         label=y,
#     599         group=group,
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/sklearn.py in ?(self, ref, **kwargs)
#    1003                 return QuantileDMatrix(
#    1004                     **kwargs, ref=ref, nthread=self.n_jobs, max_bin=self.max_bin
#    1005                 )
#    1006             except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
# -> 1007                 pass
#    1008         return DMatrix(**kwargs, nthread=self.n_jobs)
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/core.py in ?(*args, **kwargs)
#     722                     raise TypeError(msg)
#     723                 warnings.warn(msg, FutureWarning)
#     724             for k, arg in zip(sig.parameters, args):
#     725                 kwargs[k] = arg
# --> 726             return func(**kwargs)
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/core.py in ?(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, max_bin, ref, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, data_split_mode)
#    1569                     "If data iterator is used as input, data like label should be "
#    1570                     "specified as batch argument."
#    1571                 )
#    1572
# -> 1573         self._init(
#    1574             data,
#    1575             ref=ref,
#    1576             label=label,
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/core.py in ?(self, data, ref, enable_categorical, **meta)
#    1628             next_callback,
#    1629             config,
#    1630             ctypes.byref(handle),
#    1631         )
# -> 1632         it.reraise()
#    1633         # delay check_call to throw intermediate exception first
#    1634         _check_call(ret)
#    1635         self.handle = handle
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/core.py in ?(self)
#     565             #  pylint 2.7.0 believes `self._exception` can be None even with `assert
#     566             #  isinstace`
#     567             exc = self._exception
#     568             self._exception = None
# --> 569             raise exc  # pylint: disable=raising-bad-type
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/core.py in ?(self, fn, dft_ret)
#     555             tb = sys.exc_info()[2]
#     556             # On dask, the worker is restarted and somehow the information is
#     557             # lost.
#     558             self._exception = e.with_traceback(tb)
# --> 559         return dft_ret
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/core.py in ?()
# --> 637         return self._handle_exception(lambda: self.next(input_data), 0)
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/data.py in ?(self, input_data)
#    1398     def next(self, input_data: Callable) -> int:
#    1399         if self.it == 1:
#    1400             return 0
#    1401         self.it += 1
# -> 1402         input_data(**self.kwargs)
#    1403         return 1
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/core.py in ?(*args, **kwargs)
#     722                     raise TypeError(msg)
#     723                 warnings.warn(msg, FutureWarning)
#     724             for k, arg in zip(sig.parameters, args):
#     725                 kwargs[k] = arg
# --> 726             return func(**kwargs)
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/core.py in ?(data, feature_names, feature_types, **kwargs)
#     613                 and ref is self._data_ref
#     614             ):
#     615                 new, cat_codes, feature_names, feature_types = self._temporary_data
#     616             else:
# --> 617                 new, cat_codes, feature_names, feature_types = _proxy_transform(
#     618                     data,
#     619                     feature_names,
#     620                     feature_types,
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/data.py in ?(data, feature_names, feature_types, enable_categorical)
#    1443         data = pd.DataFrame(data)
#    1444     if _is_arrow(data):
#    1445         data = _arrow_transform(data)
#    1446     if _is_pandas_df(data):
# -> 1447         df, feature_names, feature_types = _transform_pandas_df(
#    1448             data, enable_categorical, feature_names, feature_types
#    1449         )
#    1450         return df, None, feature_names, feature_types
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/data.py in ?(data, enable_categorical, feature_names, feature_types, meta)
#     607     feature_names, feature_types = pandas_feature_info(
#     608         data, meta, feature_names, feature_types, enable_categorical
#     609     )
#     610
# --> 611     arrays = pandas_transform_data(data)
#     612     return PandasTransformed(arrays), feature_names, feature_types
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/data.py in ?(data)
#     546             if _is_np_array_like(arr):
#     547                 arr, _ = _ensure_np_dtype(arr, arr.dtype)
#     548             result.append(arr)
#     549         else:
# --> 550             result.append(oth_type(data[col]))
#     551
#     552     # FIXME(jiamingy): Investigate the possibility of using dataframe protocol or arrow
#     553     # IPC format for pandas so that we can apply the data transformation inside XGBoost
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/xgboost/data.py in ?(ser)
#     511     def oth_type(ser: pd.Series) -> np.ndarray:
#     512         # The dtypes module is added in 1.25.
#     513         npdtypes = np.lib.NumpyVersion(np.__version__) > np.lib.NumpyVersion("1.25.0")
#     514         npdtypes = npdtypes and isinstance(
# --> 515             ser.dtype,
#     516             (
#     517                 # pylint: disable=no-member
#     518                 np.dtypes.Float32DType,  # type: ignore
#
# /opt/conda/envs/survival-env/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'
